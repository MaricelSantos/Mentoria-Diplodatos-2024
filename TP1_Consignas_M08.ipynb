# %% [markdown]
# # Práctico 1 de análisis y visualización
#
# **Entrega 01/07**
#
# Reconoceremos el data set y realizaremos visualizaciones tratando de responder las siguientes preguntas.
#
# ¿Qué tipo de datos tenemos?
#
# ¿Cuántas variables (o features) tenemos?
#
# ¿Tenemos datos duplicados?
#
# ¿Existen valores faltantes?
#
# ¿Existe correlación entre nuestras features? ¿qué significa? ¿qué decisiones podemos tomar al respecto?
#
# ¿Cómo es la distribución de cada una de las variables? ¿Existen outliers?
#
# ¿Son importantes las unidades de las variables? ¿Debemos convertirlas?
#
# Comencemos a pensar en el siguiente práctico, a grandes rasgos ¿Cómo podemos tratar las variables para nuestro problema en particular?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import missingno as msno
import seaborn as sns
sns.set_context('talk')

# %%
agua_df = pd.read_csv('https://raw.githubusercontent.com/MaricelSantos/Mentoria-Diplodatos-2024/main/Conexiones_Transparentes.csv')

agua_df
# Out:
#     codigo  orden                        sitios       fecha   año    campaña  \
# 0    TI001    1.0  Canal Villanueva y Río Luján   23/2/2022  2022     Verano
# 1    TI001    1.0  Canal Villanueva y Río Luján    4/5/2022  2022      otoño
# 2    TI001    1.0  Canal Villanueva y Río Luján   23/8/2022  2022   invierno
# 3    TI001    1.0  Canal Villanueva y Río Luján  31/10/2022  2022  Primavera
# 4    TI006    2.0  Río Lujan y Arroyo Caraguatá   23/2/2022  2022     Verano
# ..     ...    ...                           ...         ...   ...        ...
# 191  QU061    NaN                           NaN         NaN   NaN   Invierno
# 192  BZ078    NaN                           NaN         NaN   NaN   Invierno
# 193  VL032    NaN                           NaN         NaN   NaN   Invierno
# 194  EN081    NaN                           NaN         NaN   NaN   Invierno
# 195  BS093    NaN                           NaN         NaN   NaN   Invierno
#
# ...

# %%
for column in agua_df.columns:
    print(f"{column}")
# Out:
# codigo
# orden
# sitios
# fecha
# año
# campaña
# tem_agua
# tem_aire
# od
# ph
# olores
# color
# espumas
# mat_susp
# colif_fecales_ufc_100ml
# escher_coli_ufc_100ml
# enteroc_ufc_100ml
# nitrato_mg_l
# nh4_mg_l
# p_total_l_mg_l
# fosf_ortofos_mg_l
# dbo_mg_l
# dqo_mg_l
# turbiedad_ntu
# hidr_deriv_petr_ug_l
# cr_total_mg_l
# cd_total_mg_l
# clorofila_a_ug_l
# microcistina_ug_l
# ica
# calidad_de_agua
# gobierno_local
# latitud
# longitud
# Poblacion_partido
# Personas_con_cloacas
# Actividad_principal
# Agricultura, ganadería, caza y silvicultura
# Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos
# Explotación de minas y canteras
# Industria Manufacturera
# Electricidad, gas y agua
# Construcción
# Servicios
# Dureza_x
# Floruros_x
# Nitritos_x
# Sólidos_totales_x
# Sulfatos_x
# Sulfuros_x
# 2,4_D_x
# 2,4_DB_x
# Aletrina_x
# AMPA_x
# Atrazina_x
# Atrazina_2_hidroxi_x
# Atrazina_desetil_x
# Atrazina_desisopropil_x
# Acetamiprid_x
# Acetoclor_x
# ...
